# %%
print("This is for creating and test virtual env")
# Out:
# This is for creating and test virtual env

# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt
plt.plot([1,2,3],[3,2,1])
plt.show()
